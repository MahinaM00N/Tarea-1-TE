# %% [markdown]
# <a href="https://colab.research.google.com/github/MahinaM00N/Tarea-1-TE/blob/main/Tarea_2_TE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tarea 2 |Técnicas Experimentales
# Nombre: Macarena Henriquez Soto ; Mahina Montoya Zavala ; Rafael Riveros Ávila

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

df1 = pd.read_csv('50.csv', sep=';', decimal=',')
df2 = pd.read_csv('100.csv', sep=';', decimal=',')
df3 = pd.read_csv('150.csv', sep=';', decimal=',')
df4 = pd.read_csv('200.csv', sep=';', decimal=',')

# %%
arr1 = df1.to_numpy() #50 partículas
arr2 = df2.to_numpy() #100 partículas
arr3 = df3.to_numpy() #150 partículas
arr4 = df4.to_numpy() #200 partículas

# %%
#Calculo de promedio

#50 partículas
print('Para 50 partículas')
t1=[arr1[0:10,0], arr1[10:20,0], arr1[20:30,0], arr1[30:40,0], arr1[40:50,0], arr1[50:60,0], arr1[60:70,0]]
n1=[arr1[0:10,1], arr1[10:20,1], arr1[20:30,1], arr1[30:40,1], arr1[40:50,1], arr1[50:60,1], arr1[60:70,1]]
cm1=[arr1[0:10,2], arr1[10:20,2], arr1[20:30,2], arr1[30:40,2], arr1[40:50,2], arr1[50:60,2], arr1[60:70,2]]

t1_prom=np.zeros(7) #Promedio tiempo (5,10,20,30,50,80,100)
for i in range(len(t1)):    
  for j in range(len(t1[i])): 
    t1_prom[i]=sum(t1[i])/len(t1[i])    
print('Promedio del tiempo medido al rededor de 5,10,20,30,50,80,100 segundos, respectivamente',t1_prom)

n1_prom=np.zeros(7)  #Promedio cantidad de partículas en el tiempo
for i in range(len(n1)):    
  for j in range(len(n1[i])): 
    n1_prom[i]=sum(n1[i])/len(n1[i])    
print('Promedio del número de partículas en el tiempo',n1_prom)

cm1_prom=np.zeros(7)  #promedio centro de masa en el tiempo
for i in range(len(cm1)):    
  for j in range(len(cm1[i])): 
    cm1_prom[i]=sum(cm1[i])/len(cm1[i])    
print('Promedio del centro de masa en el tiempo',cm1_prom)

#100 partículas
print('Para 100 partículas')
t2=[arr2[0:10,0], arr2[10:20,0], arr2[20:30,0], arr2[30:40,0], arr2[40:50,0], arr2[50:60,0], arr2[60:70,0]]
n2=[arr2[0:10,1], arr2[10:20,1], arr2[20:30,1], arr2[30:40,1], arr2[40:50,1], arr2[50:60,1], arr2[60:70,1]]
cm2=[arr2[0:10,2], arr2[10:20,2], arr2[20:30,2], arr2[30:40,2], arr2[40:50,2], arr2[50:60,2], arr2[60:70,2]]

t2_prom=np.zeros(7) #Promedio tiempo (5,10,20,30,50,80,100)
for i in range(len(t2)):    
  for j in range(len(t2[i])): 
    t2_prom[i]=sum(t2[i])/len(t2[i])    
print('Promedio del tiempo medido al rededor de 5,10,20,30,50,80,100 segundos, respectivamente',t2_prom)

n2_prom=np.zeros(7)  #Promedio cantidad de partículas en el tiempo
for i in range(len(n2)):    
  for j in range(len(n2[i])): 
    n2_prom[i]=sum(n2[i])/len(n2[i])    
print('Promedio del número de partículas en el tiempo',n2_prom)

cm2_prom=np.zeros(7)  #promedio centro de masa en el tiempo
for i in range(len(cm2)):    
  for j in range(len(cm2[i])): 
    cm2_prom[i]=sum(cm2[i])/len(cm2[i])    
print('Promedio del centro de masa en el tiempo',cm2_prom)

#150 partículas
print('Para 150 partículas')
t3=[arr3[0:10,0], arr3[10:20,0], arr3[20:30,0], arr3[30:40,0], arr3[40:50,0], arr3[50:60,0], arr3[60:70,0]]
n3=[arr3[0:10,1], arr3[10:20,1], arr3[20:30,1], arr3[30:40,1], arr3[40:50,1], arr3[50:60,1], arr3[60:70,1]]
cm3=[arr3[0:10,2], arr3[10:20,2], arr3[20:30,2], arr3[30:40,2], arr3[40:50,2], arr3[50:60,2], arr3[60:70,2]]

t3_prom=np.zeros(7) #Promedio tiempo (5,10,20,30,50,80,100)
for i in range(len(t3)):    
  for j in range(len(t3[i])): 
    t3_prom[i]=sum(t3[i])/len(t3[i])    
print('Promedio del tiempo medido al rededor de 5,10,20,30,50,80,100 segundos, respectivamente',t3_prom)

n3_prom=np.zeros(7)  #Promedio cantidad de partículas en el tiempo
for i in range(len(n3)):    
  for j in range(len(n3[i])): 
    n3_prom[i]=sum(n3[i])/len(n3[i])    
print('Promedio del número de partículas en el tiempo',n1_prom)

cm3_prom=np.zeros(7)  #promedio centro de masa en el tiempo
for i in range(len(cm3)):    
  for j in range(len(cm3[i])): 
    cm3_prom[i]=sum(cm3[i])/len(cm3[i])    
print('Promedio del centro de masa en el tiempo',cm3_prom)

#200 partículas
print('Para 200 partículas')
t4=[arr3[0:10,0], arr4[10:20,0], arr4[20:30,0], arr4[30:40,0], arr4[40:50,0], arr4[50:60,0], arr4[60:70,0]]
n4=[arr3[0:10,1], arr4[10:20,1], arr4[20:30,1], arr4[30:40,1], arr4[40:50,1], arr4[50:60,1], arr4[60:70,1]]
cm4=[arr3[0:10,2], arr4[10:20,2], arr4[20:30,2], arr4[30:40,2], arr4[40:50,2], arr4[50:60,2], arr4[60:70,2]]

t4_prom=np.zeros(7) #Promedio tiempo (5,10,20,30,50,80,100)
for i in range(len(t4)):    
  for j in range(len(t4[i])): 
    t4_prom[i]=sum(t4[i])/len(t4[i])    
print('Promedio del tiempo medido al rededor de 5,10,20,30,50,80,100 segundos, respectivamente',t4_prom)

n4_prom=np.zeros(7)  #Promedio cantidad de partículas en el tiempo
for i in range(len(n4)):    
  for j in range(len(n4[i])): 
    n4_prom[i]=sum(n4[i])/len(n4[i])
print('Promedio del número de partículas en el tiempo',n4_prom)

cm4_prom=np.zeros(7)  #promedio centro de masa en el tiempo
for i in range(len(cm4)):
  for j in range(len(cm4[i])):
    cm4_prom[i]=sum(cm4[i])/len(cm4[i])
print('Promedio del centro de masa en el tiempo',cm4_prom)

#Todos los datos
asd=np.array([t1_prom, n1_prom, cm1_prom, t2_prom, n2_prom, cm2_prom, t3_prom, n3_prom, cm3_prom, t4_prom, n4_prom, cm4_prom])
# Out:
# Para 50 partículas
# Promedio del tiempo medido al rededor de 5,10,20,30,50,80,100 segundos, respectivamente [  5.444  10.288  20.264  30.38   50.344  80.37  100.267]
# Promedio del número de partículas en el tiempo [ 6.  12.3 22.7 29.6 25.  24.4 25. ]
# Promedio del centro de masa en el tiempo [4.35 5.2  7.9  8.75 7.9  7.9  8.05]
# Para 100 partículas
# Promedio del tiempo medido al rededor de 5,10,20,30,50,80,100 segundos, respectivamente [ 5.525  9.942 19.99  29.784 49.929 80.287 98.742]
# Promedio del número de partículas en el tiempo [11.1 20.1 44.5 55.4 44.6 51.5 47.1]
# Promedio del centro de masa en el tiempo [4.  5.1 7.6 8.4 7.5 8.  7.9]
# Para 150 partículas
# Promedio del tiempo medido al rededor de 5,10,20,30,50,80,100 segundos, respectivamente [  5.559  10.238  20.193  30.165  50.154  80.315 100.27 ]
# Promedio del número de partículas en el tiempo [ 6.  12.3 22.7 29.6 25.  24.4 25. ]
# Promedio del centro de masa en el tiempo [4.4 5.6 7.9 8.6 7.3 8.3 8. ]
# ...

# %%
#Varianza y desviación estandar para 50 partículas
print('Para 50 partículas')
t1_5=t1[0]  #tiempo 5 s
cuadt1_5=np.zeros(10)
for i in range(10):
  cuadt1_5[i]=(t1_5[i]-t1_prom[0])**(2)
  vart1_5=(1/len(t1_5))*sum(cuadt1_5)
  desvt1_5= (vart1_5)**(1/2)
print('la varianza del tiempo medido alrededor de 5 segundos', vart1_5)      
print('la desviación estándar del tiempo medido alrededor de 5 segundos',desvt1_5)

t1_10=t1[1]  #tiempo 10 s 
cuadt1_10=np.zeros(10)
for i in range(10):
  cuadt1_10[i]=(t1_10[i]-t1_prom[1])**(2)
  vart1_10=(1/len(t1_10))*sum(cuadt1_10)
  desvt1_10= (vart1_10)**(1/2)
print('la varianza del tiempo medido alrededor de 10 segundos',vart1_10)
print('la desviación estándar del tiempo medido alrededor de 10 segundos',desvt1_10)

t1_20=t1[2]  #tiempo 20 s 
cuadt1_20=np.zeros(10)
for i in range(10):
  cuadt1_20[i]=(t1_20[i]-t1_prom[2])**(2)
  vart1_20=(1/len(t1_20))*sum(cuadt1_20)
  desvt1_20= (vart1_20)**(1/2)
print('la varianza del tiempo medido al rededor de 20 segundos',vart1_20)
print('la desviación estándar del tiempo medido alrededor de 20 segundos',desvt1_20)

t1_30=t1[3]  #tiempo 30 s 
cuadt1_30=np.zeros(10)
for i in range(10):
  cuadt1_30[i]=(t1_30[i]-t1_prom[3])**(2)
  vart1_30=(1/len(t1_30))*sum(cuadt1_30)
  desvt1_30= (vart1_30)**(1/2)
print('la varianza del tiempo medido alrededor de 30 segundos',vart1_30)
print('la desviación estándar del tiempo medido alrededor de 30 segundos',desvt1_30)

t1_50=t1[4]  #tiempo 50 s 
cuadt1_50=np.zeros(10)
for i in range(10):
  cuadt1_50[i]=(t1_50[i]-t1_prom[4])**(2)
  vart1_50=(1/len(t1_50))*sum(cuadt1_50)
  desvt1_50= (vart1_50)**(1/2)
print('la varianza del tiempo medido alrededor de 50 segundos',vart1_50)
print('la desviación estándar del tiempo medido alrededor de 50 segundos',desvt1_50)

t1_80=t1[5]  #tiempo 80 s 
cuadt1_80=np.zeros(10)
for i in range(10):
  cuadt1_80[i]=(t1_80[i]-t1_prom[5])**(2)
  vart1_80=(1/len(t1_80))*sum(cuadt1_80)
  desvt1_80= (vart1_80)**(1/2)
print('la varianza del tiempo medido alrededor de 80 segundos',vart1_80)
print('la desviación estándar del tiempo medido alrededor de 50 segundos',desvt1_80)

t1_100=t1[6]  #tiempo 100 s 
cuadt1_100=np.zeros(10)
for i in range(10):
  cuadt1_100[i]=(t1_100[i]-t1_prom[6])**(2)
  vart1_100=(1/len(t1_100))*sum(cuadt1_100)
  desvt1_100= (vart1_100)**(1/2)
print('la varianza del tiempo medido alrededor de 100 segundos',vart1_100)
print('la desviación estándar del tiempo medido alrededor de 100 segundos',desvt1_100)

n1_5=n1[0]  #numero de particulas en el intervalo 5 s
cuadn1_5=np.zeros(10)
for i in range(10):
  cuadn1_5[i]=(n1_5[i]-n1_prom[0])**(2)
  varn1_5=(1/len(n1_5))*sum(cuadn1_5)
  desvn1_5= (varn1_5)**(1/2)
print('la varianza del número de partículas, alrededor de 5 segundos',varn1_5)
print('la desviación estándar del número de partículas, alrededor de 5 segundos',desvn1_5)

n1_10=n1[1]  #numero de particulas en el intervalo 10 s
cuadn1_10=np.zeros(10)
for i in range(10):
  cuadn1_10[i]=(n1_10[i]-n1_prom[1])**(2)
  varn1_10=(1/len(n1_10))*sum(cuadn1_10)
  desvn1_10= (varn1_10)**(1/2)
print('la varianza del número de partículas, alrededor de 10 segundos', varn1_10)
print('la desviación estándar del número de partículas, alrededor de 10 segundos',desvn1_10)

n1_20=n1[2]  #numero de particulas en el intervalo 20 s
cuadn1_20=np.zeros(10)
for i in range(10):
  cuadn1_20[i]=(n1_20[i]-n1_prom[2])**(2)
  varn1_20=(1/len(n1_20))*sum(cuadn1_20)
  desvn1_20= (varn1_20)**(1/2)
print('la varianza del número de partículas, alrededor de 20 segundos',varn1_20)
print('la desviación estándar del número de partículas, alrededor de 20 segundos',desvn1_20)

n1_30=n1[3]  #numero de particulas en el intervalo 30 s
cuadn1_30=np.zeros(10)
for i in range(10):
  cuadn1_30[i]=(n1_30[i]-n1_prom[3])**(2)
  varn1_30=(1/len(n1_30))*sum(cuadn1_30)
  desvn1_30= (varn1_30)**(1/2)
print('la varianza del número de partículas, alrededor de 30 segundos',varn1_30)
print('la desviación estándar del número de partículas, alrededor de 30 segundos',desvn1_30)

n1_50=n1[4]  #numero de particulas en el intervalo 50 s
cuadn1_50=np.zeros(10)
for i in range(10):
  cuadn1_50[i]=(n1_50[i]-n1_prom[4])**(2)
  varn1_50=(1/len(n1_50))*sum(cuadn1_50)
  desvn1_50= (varn1_50)**(1/2)
print('la varianza del número de partículas, alrededor de 50 segundos',varn1_50)
print('la desviación estándar del número de partículas, alrededor de 50 segundos',desvn1_50)

n1_80=n1[5]  #numero de particulas en el intervalo 50 s
cuadn1_80=np.zeros(10)
for i in range(10):
  cuadn1_80[i]=(n1_80[i]-n1_prom[5])**(2)
  varn1_80=(1/len(n1_80))*sum(cuadn1_80)
  desvn1_80= (varn1_80)**(1/2)
print('la varianza del número de partículas, alrededor de 80 segundos',varn1_80)
print('la desviación estándar del número de partículas, alrededor de 80 segundos',desvn1_80)

n1_100=n1[6]  #numero de particulas en el intervalo 100 s
cuadn1_100=np.zeros(10)
for i in range(10):
  cuadn1_100[i]=(n1_100[i]-n1_prom[6])**(2)
  varn1_100=(1/len(n1_100))*sum(cuadn1_100)
  desvn1_100= (varn1_100)**(1/2)
print('la varianza del número de partículas, alrededor de 100 segundos',varn1_100)
print('la desviación estándar del número de partículas, alrededor de 100 segundos',desvn1_100)

cm1_5=cm1[0]  #centro de masa en el intervalo 5 s
cuadcm1_5=np.zeros(10)
for i in range(10):
  cuadcm1_5[i]=(cm1_5[i]-cm1_prom[0])**(2)
  varcm1_5=(1/len(cm1_5))*sum(cuadcm1_5)
  desvcm1_5= (varcm1_5)**(1/2)
print('la varianza del centro de masa, alrededor de 5 segundos',varcm1_5)
print('la desviación estándar del centro de masa, alrededor de 5 segundos', desvcm1_5)

cm1_10=cm1[1]  #centro de masa en el intervalo 10 s
cuadcm1_10=np.zeros(10)
for i in range(10):
  cuadcm1_10[i]=(cm1_10[i]-cm1_prom[1])**(2)
  varcm1_10=(1/len(cm1_10))*sum(cuadcm1_10)
  desvcm1_10= (varcm1_10)**(1/2)
print('la varianza del centro de masa, al rededor de 10 segundos',varcm1_10)
print('la desviación estándar del centro de masa, alrededor de 10 segundos',desvcm1_10)

cm1_20=cm1[2]  #centro de masa en el intervalo 20 s
cuadcm1_20=np.zeros(10)
for i in range(10):
  cuadcm1_20[i]=(cm1_20[i]-cm1_prom[2])**(2)
  varcm1_20=(1/len(cm1_20))*sum(cuadcm1_20)
  desvcm1_20= (varcm1_20)**(1/2)
print('la varianza del centro de masa, al rededor de 20 segundos',varcm1_20)
print('la desviación estándar del centro de masa, alrededor de 20 segundos',desvcm1_20)

cm1_30=cm1[3]  #centro de masa en el intervalo 30 s
cuadcm1_30=np.zeros(10)
for i in range(10):
  cuadcm1_30[i]=(cm1_30[i]-cm1_prom[3])**(2)
  varcm1_30=(1/len(cm1_30))*sum(cuadcm1_30)
  desvcm1_30= (varcm1_30)**(1/2)
print('la varianza del centro de masa, al rededor de 30 segundos',varcm1_30)
print('la desviación estándar del centro de masa, alrededor de 30 segundos', desvcm1_30)

cm1_50=cm1[4]  #centro de masa en el intervalo 50 s
cuadcm1_50=np.zeros(10)
for i in range(10):
  cuadcm1_50[i]=(cm1_50[i]-cm1_prom[4])**(2)
  varcm1_50=(1/len(cm1_50))*sum(cuadcm1_50)
  desvcm1_50= (varcm1_50)**(1/2)
print('la varianza del centro de masa, al rededor de 50 segundos',varcm1_50)
print('la desviación estándar del centro de masa, alrededor de 50 segundos',desvcm1_50)

cm1_80=cm1[5]  #centro de masa en el intervalo 80 s
cuadcm1_80=np.zeros(10)
for i in range(10):
  cuadcm1_80[i]=(cm1_80[i]-cm1_prom[6])**(2)
  varcm1_80=(1/len(cm1_80))*sum(cuadcm1_80)
  desvcm1_80= (varcm1_80)**(1/2)
print('la varianza del centro de masa, al rededor de 80 segundos',varcm1_80)
print('la desviación estándar del centro de masa, alrededor de 80 segundos',desvcm1_80)

cm1_100=cm1[6]  #centro de masa en el intervalo 100 s
cuadcm1_100=np.zeros(10)
for i in range(10):
  cuadcm1_100[i]=(cm1_100[i]-cm1_prom[6])**(2)
  varcm1_100=(1/len(cm1_100))*sum(cuadcm1_100)
  desvcm1_100= (varcm1_100)**(1/2)
print('la varianza del centro de masa, al rededor de 100 segundos',varcm1_100)
print('la desviación estándar del centro de masa, alrededor de 100 segundos',desvcm1_100)
# Out:
# Para 50 partículas
# la varianza del tiempo medido alrededor de 5 segundos 0.05404400000000001
# la desviación estándar del tiempo medido alrededor de 5 segundos 0.23247365442131288
# la varianza del tiempo medido alrededor de 10 segundos 0.01107600000000003
# la desviación estándar del tiempo medido alrededor de 10 segundos 0.1052425769353831
# la varianza del tiempo medido al rededor de 20 segundos 0.006403999999999951
# la desviación estándar del tiempo medido alrededor de 20 segundos 0.08002499609496992
# la varianza del tiempo medido alrededor de 30 segundos 0.03468000000000014
# la desviación estándar del tiempo medido alrededor de 30 segundos 0.18622566955175684
# la varianza del tiempo medido alrededor de 50 segundos 0.06148399999999994
# la desviación estándar del tiempo medido alrededor de 50 segundos 0.24795967414077624
# la varianza del tiempo medido alrededor de 80 segundos 0.05533999999999953
# ...

# %%
#Varianza y desviación estandar para 100 partículas
print('Para 100 partículas')

t2_5=t2[0]  #tiempo 5 s
cuadt2_5=np.zeros(10)
for i in range(10):
  cuadt2_5[i]=(t2_5[i]-t2_prom[0])**(2)
  vart2_5=(1/len(t2_5))*sum(cuadt2_5)
  desvt2_5= (vart2_5)**(1/2)
print('la varianza del tiempo medido alrededor de 5 segundos', vart2_5)      
print('la desviación estándar del tiempo medido alrededor de 5 segundos',desvt2_5)

t2_10=t2[1]  #tiempo 10 s 
cuadt2_10=np.zeros(10)
for i in range(10):
  cuadt2_10[i]=(t2_10[i]-t2_prom[1])**(2)
  vart2_10=(1/len(t2_10))*sum(cuadt2_10)
  desvt2_10= (vart2_10)**(1/2)
print('la varianza del tiempo medido alrededor de 10 segundos',vart2_10)
print('la desviación estándar del tiempo medido alrededor de 10 segundos',desvt2_10)

t2_20=t2[2]  #tiempo 20 s 
cuadt2_20=np.zeros(10)
for i in range(10):
  cuadt2_20[i]=(t2_20[i]-t2_prom[2])**(2)
  vart2_20=(1/len(t2_20))*sum(cuadt2_20)
  desvt2_20= (vart2_20)**(1/2)
print('la varianza del tiempo medido al rededor de 20 segundos',vart2_20)
print('la desviación estándar del tiempo medido alrededor de 20 segundos',desvt2_20)

t2_30=t2[3]  #tiempo 30 s 
cuadt2_30=np.zeros(10)
for i in range(10):
  cuadt2_30[i]=(t2_30[i]-t2_prom[3])**(2)
  vart2_30=(1/len(t2_30))*sum(cuadt2_30)
  desvt2_30= (vart2_30)**(1/2)
print('la varianza del tiempo medido alrededor de 30 segundos',vart2_30)
print('la desviación estándar del tiempo medido alrededor de 30 segundos',desvt2_30)

t2_50=t2[4]  #tiempo 50 s 
cuadt2_50=np.zeros(10)
for i in range(10):
  cuadt2_50[i]=(t2_50[i]-t2_prom[4])**(2)
  vart2_50=(1/len(t2_50))*sum(cuadt2_50)
  desvt2_50= (vart2_50)**(1/2)
print('la varianza del tiempo medido alrededor de 50 segundos',vart2_50)
print('la desviación estándar del tiempo medido alrededor de 50 segundos',desvt2_50)

t2_80=t2[5]  #tiempo 80 s 
cuadt2_80=np.zeros(10)
for i in range(10):
  cuadt2_80[i]=(t1_80[i]-t2_prom[5])**(2)
  vart2_80=(1/len(t2_80))*sum(cuadt2_80)
  desvt2_80= (vart2_80)**(1/2)
print('la varianza del tiempo medido alrededor de 80 segundos',vart2_80)
print('la desviación estándar del tiempo medido alrededor de 50 segundos',desvt2_80)

t2_100=t2[6]  #tiempo 100 s 
cuadt2_100=np.zeros(10)
for i in range(10):
  cuadt2_100[i]=(t2_100[i]-t2_prom[6])**(2)
  vart2_100=(1/len(t2_100))*sum(cuadt2_100)
  desvt2_100= (vart2_100)**(1/2)
print('la varianza del tiempo medido alrededor de 100 segundos',vart2_100)
print('la desviación estándar del tiempo medido alrededor de 100 segundos',desvt2_100)

n2_5=n2[0]  #numero de particulas en el intervalo 5 s
cuadn2_5=np.zeros(10)
for i in range(10):
  cuadn2_5[i]=(n2_5[i]-n2_prom[0])**(2)
  varn2_5=(1/len(n2_5))*sum(cuadn2_5)
  desvn2_5= (varn2_5)**(1/2)
print('la varianza del número de partículas, alrededor de 5 segundos',varn2_5)
print('la desviación estándar del número de partículas, alrededor de 5 segundos',desvn2_5)

n2_10=n2[1]  #numero de particulas en el intervalo 10 s
cuadn2_10=np.zeros(10)
for i in range(10):
  cuadn2_10[i]=(n2_10[i]-n2_prom[1])**(2)
  varn2_10=(1/len(n2_10))*sum(cuadn2_10)
  desvn2_10= (varn2_10)**(1/2)
print('la varianza del número de partículas, alrededor de 10 segundos', varn2_10)
print('la desviación estándar del número de partículas, alrededor de 10 segundos',desvn2_10)

n2_20=n2[2]  #numero de particulas en el intervalo 20 s
cuadn2_20=np.zeros(10)
for i in range(10):
  cuadn2_20[i]=(n1_20[i]-n2_prom[2])**(2)
  varn2_20=(1/len(n2_20))*sum(cuadn2_20)
  desvn2_20= (varn2_20)**(1/2)
print('la varianza del número de partículas, alrededor de 20 segundos',varn2_20)
print('la desviación estándar del número de partículas, alrededor de 20 segundos',desvn2_20)

n2_30=n2[3]  #numero de particulas en el intervalo 30 s
cuadn2_30=np.zeros(10)
for i in range(10):
  cuadn2_30[i]=(n2_30[i]-n2_prom[3])**(2)
  varn2_30=(1/len(n2_30))*sum(cuadn2_30)
  desvn2_30= (varn2_30)**(1/2)
print('la varianza del número de partículas, alrededor de 30 segundos',varn2_30)
print('la desviación estándar del número de partículas, alrededor de 30 segundos',desvn2_30)

n2_50=n2[4]  #numero de particulas en el intervalo 50 s
cuadn2_50=np.zeros(10)
for i in range(10):
  cuadn2_50[i]=(n2_50[i]-n2_prom[4])**(2)
  varn2_50=(1/len(n2_50))*sum(cuadn2_50)
  desvn2_50= (varn2_50)**(1/2)
print('la varianza del número de partículas, alrededor de 50 segundos',varn2_50)
print('la desviación estándar del número de partículas, alrededor de 50 segundos',desvn2_50)

n2_80=n2[5]  #numero de particulas en el intervalo 50 s
cuadn2_80=np.zeros(10)
for i in range(10):
  cuadn2_80[i]=(n2_80[i]-n2_prom[5])**(2)
  varn2_80=(1/len(n2_80))*sum(cuadn2_80)
  desvn2_80= (varn2_80)**(1/2)
print('la varianza del número de partículas, alrededor de 80 segundos',varn2_80)
print('la desviación estándar del número de partículas, alrededor de 80 segundos',desvn2_80)

n2_100=n2[6]  #numero de particulas en el intervalo 100 s
cuadn2_100=np.zeros(10)
for i in range(10):
  cuadn1_100[i]=(n2_100[i]-n2_prom[6])**(2)
  varn2_100=(1/len(n2_100))*sum(cuadn2_100)
  desvn2_100= (varn2_100)**(1/2)
print('la varianza del número de partículas, alrededor de 100 segundos',varn2_100)
print('la desviación estándar del número de partículas, alrededor de 100 segundos',desvn2_100)

cm2_5=cm2[0]  #centro de masa en el intervalo 5 s
cuadcm2_5=np.zeros(10)
for i in range(10):
  cuadcm2_5[i]=(cm2_5[i]-cm2_prom[0])**(2)
  varcm2_5=(1/len(cm2_5))*sum(cuadcm2_5)
  desvcm2_5= (varcm2_5)**(1/2)
print('la varianza del centro de masa, alrededor de 5 segundos',varcm2_5)
print('la desviación estándar del centro de masa, alrededor de 5 segundos', desvcm2_5)

cm2_10=cm2[1]  #centro de masa en el intervalo 10 s
cuadcm2_10=np.zeros(10)
for i in range(10):
  cuadcm2_10[i]=(cm2_10[i]-cm2_prom[1])**(2)
  varcm2_10=(1/len(cm2_10))*sum(cuadcm2_10)
  desvcm2_10= (varcm1_10)**(1/2)
print('la varianza del centro de masa, al rededor de 10 segundos',varcm2_10)
print('la desviación estándar del centro de masa, alrededor de 10 segundos',desvcm2_10)

cm2_20=cm2[2]  #centro de masa en el intervalo 20 s
cuadcm2_20=np.zeros(10)
for i in range(10):
  cuadcm2_20[i]=(cm2_20[i]-cm2_prom[2])**(2)
  varcm2_20=(1/len(cm2_20))*sum(cuadcm2_20)
  desvcm2_20= (varcm2_20)**(1/2)
print('la varianza del centro de masa, al rededor de 20 segundos',varcm2_20)
print('la desviación estándar del centro de masa, alrededor de 20 segundos',desvcm2_20)

cm2_30=cm2[3]  #centro de masa en el intervalo 30 s
cuadcm2_30=np.zeros(10)
for i in range(10):
  cuadcm2_30[i]=(cm2_30[i]-cm2_prom[3])**(2)
  varcm2_30=(1/len(cm2_30))*sum(cuadcm2_30)
  desvcm2_30= (varcm2_30)**(1/2)
print('la varianza del centro de masa, al rededor de 30 segundos',varcm2_30)
print('la desviación estándar del centro de masa, alrededor de 30 segundos', desvcm2_30)

cm2_50=cm1[4]  #centro de masa en el intervalo 50 s
cuadcm2_50=np.zeros(10)
for i in range(10):
  cuadcm2_50[i]=(cm2_50[i]-cm2_prom[4])**(2)
  varcm2_50=(1/len(cm2_50))*sum(cuadcm2_50)
  desvcm2_50= (varcm2_50)**(1/2)
print('la varianza del centro de masa, al rededor de 50 segundos',varcm2_50)
print('la desviación estándar del centro de masa, alrededor de 50 segundos',desvcm2_50)

cm2_80=cm2[5]  #centro de masa en el intervalo 80 s
cuadcm2_80=np.zeros(10)
for i in range(10):
  cuadcm2_80[i]=(cm2_80[i]-cm2_prom[6])**(2)
  varcm2_80=(1/len(cm2_80))*sum(cuadcm2_80)
  desvcm2_80= (varcm2_80)**(1/2)
print('la varianza del centro de masa, al rededor de 80 segundos',varcm2_80)
print('la desviación estándar del centro de masa, alrededor de 80 segundos',desvcm2_80)

cm2_100=cm2[6]  #centro de masa en el intervalo 100 s
cuadcm2_100=np.zeros(10)
for i in range(10):
  cuadcm2_100[i]=(cm2_100[i]-cm2_prom[6])**(2)
  varcm2_100=(1/len(cm2_100))*sum(cuadcm2_100)
  desvcm2_100= (varcm2_100)**(1/2)
print('la varianza del centro de masa, al rededor de 100 segundos',varcm2_100)
print('la desviación estándar del centro de masa, alrededor de 100 segundos',desvcm2_100)
# Out:
# Para 100 partículas
# la varianza del tiempo medido alrededor de 5 segundos 0.062985
# la desviación estándar del tiempo medido alrededor de 5 segundos 0.25096812546616354
# la varianza del tiempo medido alrededor de 10 segundos 0.05373599999999992
# la desviación estándar del tiempo medido alrededor de 10 segundos 0.23181026724457207
# la varianza del tiempo medido al rededor de 20 segundos 0.054899999999999796
# la desviación estándar del tiempo medido alrededor de 20 segundos 0.2343074902771992
# la varianza del tiempo medido alrededor de 30 segundos 0.13106400000000012
# la desviación estándar del tiempo medido alrededor de 30 segundos 0.36202762325546395
# la varianza del tiempo medido alrededor de 50 segundos 0.15886899999999904
# la desviación estándar del tiempo medido alrededor de 50 segundos 0.39858374276931946
# la varianza del tiempo medido alrededor de 80 segundos 0.06222899999999855
# la desviación estándar del tiempo medido alrededor de 50 segundos 0.249457411194774
# ...

# %%
#Varianza y desviación estandar para 150 partículas
print('Para 150 partículas')

t3_5=t3[0]  #tiempo 5 s
cuadt3_5=np.zeros(10)
for i in range(10):
  cuadt3_5[i]=(t3_5[i]-t3_prom[0])**(2)
  vart3_5=(1/len(t3_5))*sum(cuadt3_5)
  desvt3_5= (vart3_5)**(1/2)
print('la varianza del tiempo medido alrededor de 5 segundos', vart3_5)      
print('la desviación estándar del tiempo medido alrededor de 5 segundos',desvt3_5)

t3_10=t3[1]  #tiempo 10 s 
cuadt3_10=np.zeros(10)
for i in range(10):
  cuadt3_10[i]=(t3_10[i]-t3_prom[1])**(2)
  vart3_10=(1/len(t3_10))*sum(cuadt3_10)
  desvt3_10= (vart3_10)**(1/2)
print('la varianza del tiempo medido alrededor de 10 segundos',vart3_10)
print('la desviación estándar del tiempo medido alrededor de 10 segundos',desvt3_10)

t3_20=t3[2]  #tiempo 20 s 
cuadt3_20=np.zeros(10)
for i in range(10):
  cuadt3_20[i]=(t3_20[i]-t3_prom[2])**(2)
  vart3_20=(1/len(t3_20))*sum(cuadt3_20)
  desvt3_20= (vart3_20)**(1/2)
print('la varianza del tiempo medido al rededor de 20 segundos',vart3_20)
print('la desviación estándar del tiempo medido alrededor de 20 segundos',desvt3_20)

t3_30=t3[3]  #tiempo 30 s 
cuadt3_30=np.zeros(10)
for i in range(10):
  cuadt3_30[i]=(t3_30[i]-t3_prom[3])**(2)
  vart3_30=(1/len(t3_30))*sum(cuadt3_30)
  desvt3_30= (vart3_30)**(1/2)
print('la varianza del tiempo medido alrededor de 30 segundos',vart3_30)
print('la desviación estándar del tiempo medido alrededor de 30 segundos',desvt3_30)

t3_50=t3[4]  #tiempo 50 s 
cuadt3_50=np.zeros(10)
for i in range(10):
  cuadt3_50[i]=(t3_50[i]-t3_prom[4])**(2)
  vart3_50=(1/len(t3_50))*sum(cuadt3_50)
  desvt3_50= (vart3_50)**(1/2)
print('la varianza del tiempo medido alrededor de 50 segundos',vart3_50)
print('la desviación estándar del tiempo medido alrededor de 50 segundos',desvt3_50)

t3_80=t3[5]  #tiempo 80 s 
cuadt3_80=np.zeros(10)
for i in range(10):
  cuadt3_80[i]=(t3_80[i]-t3_prom[5])**(2)
  vart3_80=(1/len(t3_80))*sum(cuadt3_80)
  desvt3_80= (vart3_80)**(1/2)
print('la varianza del tiempo medido alrededor de 80 segundos',vart3_80)
print('la desviación estándar del tiempo medido alrededor de 50 segundos',desvt3_80)

t3_100=t3[6]  #tiempo 100 s 
cuadt3_100=np.zeros(10)
for i in range(10):
  cuadt3_100[i]=(t3_100[i]-t3_prom[6])**(2)
  vart3_100=(1/len(t3_100))*sum(cuadt3_100)
  desvt3_100= (vart3_100)**(1/2)
print('la varianza del tiempo medido alrededor de 100 segundos',vart3_100)
print('la desviación estándar del tiempo medido alrededor de 100 segundos',desvt3_100)

n3_5=n3[0]  #numero de particulas en el intervalo 5 s
cuadn3_5=np.zeros(10)
for i in range(10):
  cuadn3_5[i]=(n3_5[i]-n3_prom[0])**(2)
  varn3_5=(1/len(n3_5))*sum(cuadn3_5)
  desvn3_5= (varn3_5)**(1/2)
print('la varianza del número de partículas, alrededor de 5 segundos',varn3_5)
print('la desviación estándar del número de partículas, alrededor de 5 segundos',desvn3_5)

n3_10=n3[1]  #numero de particulas en el intervalo 10 s
cuadn3_10=np.zeros(10)
for i in range(10):
  cuadn3_10[i]=(n3_10[i]-n3_prom[1])**(2)
  varn3_10=(1/len(n3_10))*sum(cuadn3_10)
  desvn3_10= (varn3_10)**(1/2)
print('la varianza del número de partículas, alrededor de 10 segundos', varn3_10)
print('la desviación estándar del número de partículas, alrededor de 10 segundos',desvn3_10)

n3_20=n3[2]  #numero de particulas en el intervalo 20 s
cuadn3_20=np.zeros(10)
for i in range(10):
  cuadn3_20[i]=(n3_20[i]-n3_prom[2])**(2)
  varn3_20=(1/len(n3_20))*sum(cuadn3_20)
  desvn3_20= (varn3_20)**(1/2)
print('la varianza del número de partículas, alrededor de 20 segundos',varn3_20)
print('la desviación estándar del número de partículas, alrededor de 20 segundos',desvn3_20)

n3_30=n3[3]  #numero de particulas en el intervalo 30 s
cuadn3_30=np.zeros(10)
for i in range(10):
  cuadn3_30[i]=(n3_30[i]-n3_prom[3])**(2)
  varn3_30=(1/len(n3_30))*sum(cuadn3_30)
  desvn3_30= (varn3_30)**(1/2)
print('la varianza del número de partículas, alrededor de 30 segundos',varn3_30)
print('la desviación estándar del número de partículas, alrededor de 30 segundos',desvn3_30)

n3_50=n3[4]  #numero de particulas en el intervalo 50 s
cuadn3_50=np.zeros(10)
for i in range(10):
  cuadn3_50[i]=(n3_50[i]-n3_prom[4])**(2)
  varn3_50=(1/len(n3_50))*sum(cuadn3_50)
  desvn3_50= (varn3_50)**(1/2)
print('la varianza del número de partículas, alrededor de 50 segundos',varn3_50)
print('la desviación estándar del número de partículas, alrededor de 50 segundos',desvn3_50)

n3_80=n3[5]  #numero de particulas en el intervalo 50 s
cuadn3_80=np.zeros(10)
for i in range(10):
  cuadn3_80[i]=(n3_80[i]-n3_prom[5])**(2)
  varn3_80=(1/len(n2_80))*sum(cuadn3_80)
  desvn3_80= (varn2_80)**(1/2)
print('la varianza del número de partículas, alrededor de 80 segundos',varn3_80)
print('la desviación estándar del número de partículas, alrededor de 80 segundos',desvn3_80)

n3_100=n3[6]  #numero de particulas en el intervalo 100 s
cuadn3_100=np.zeros(10)
for i in range(10):
  cuadn3_100[i]=(n3_100[i]-n3_prom[6])**(2)
  varn3_100=(1/len(n3_100))*sum(cuadn3_100)
  desvn3_100= (varn3_100)**(1/2)
print('la varianza del número de partículas, alrededor de 100 segundos',varn3_100)
print('la desviación estándar del número de partículas, alrededor de 100 segundos',desvn3_100)

cm3_5=cm3[0]  #centro de masa en el intervalo 5 s
cuadcm3_5=np.zeros(10)
for i in range(10):
  cuadcm3_5[i]=(cm3_5[i]-cm3_prom[0])**(2)
  varcm3_5=(1/len(cm3_5))*sum(cuadcm3_5)
  desvcm3_5= (varcm3_5)**(1/2)
print('la varianza del centro de masa, alrededor de 5 segundos',varcm3_5)
print('la desviación estándar del centro de masa, alrededor de 5 segundos', desvcm3_5)

cm3_10=cm3[1]  #centro de masa en el intervalo 10 s
cuadcm3_10=np.zeros(10)
for i in range(10):
  cuadcm3_10[i]=(cm3_10[i]-cm3_prom[1])**(2)
  varcm3_10=(1/len(cm3_10))*sum(cuadcm3_10)
  desvcm3_10= (varcm3_10)**(1/2)
print('la varianza del centro de masa, al rededor de 10 segundos',varcm3_10)
print('la desviación estándar del centro de masa, alrededor de 10 segundos',desvcm3_10)

cm3_20=cm3[2]  #centro de masa en el intervalo 20 s
cuadcm3_20=np.zeros(10)
for i in range(10):
  cuadcm3_20[i]=(cm3_20[i]-cm3_prom[2])**(2)
  varcm3_20=(1/len(cm3_20))*sum(cuadcm2_20)
  desvcm3_20= (varcm3_20)**(1/2)
print('la varianza del centro de masa, al rededor de 20 segundos',varcm3_20)
print('la desviación estándar del centro de masa, alrededor de 20 segundos',desvcm3_20)

cm3_30=cm3[3]  #centro de masa en el intervalo 30 s
cuadcm3_30=np.zeros(10)
for i in range(10):
  cuadcm3_30[i]=(cm3_30[i]-cm3_prom[3])**(2)
  varcm3_30=(1/len(cm3_30))*sum(cuadcm3_30)
  desvcm3_30= (varcm3_30)**(1/2)
print('la varianza del centro de masa, al rededor de 30 segundos',varcm3_30)
print('la desviación estándar del centro de masa, alrededor de 30 segundos', desvcm3_30)

cm3_50=cm3[4]  #centro de masa en el intervalo 50 s
cuadcm3_50=np.zeros(10)
for i in range(10):
  cuadcm3_50[i]=(cm3_50[i]-cm3_prom[4])**(2)
  varcm3_50=(1/len(cm3_50))*sum(cuadcm3_50)
  desvcm3_50= (varcm3_50)**(1/2)
print('la varianza del centro de masa, al rededor de 50 segundos',varcm3_50)
print('la desviación estándar del centro de masa, alrededor de 50 segundos',desvcm3_50)

cm3_80=cm3[5]  #centro de masa en el intervalo 80 s
cuadcm3_80=np.zeros(10)
for i in range(10):
  cuadcm3_80[i]=(cm3_80[i]-cm3_prom[6])**(2)
  varcm3_80=(1/len(cm3_80))*sum(cuadcm3_80)
  desvcm3_80= (varcm3_80)**(1/2)
print('la varianza del centro de masa, al rededor de 80 segundos',varcm3_80)
print('la desviación estándar del centro de masa, alrededor de 80 segundos',desvcm3_80)

cm3_100=cm3[6]  #centro de masa en el intervalo 100 s
cuadcm3_100=np.zeros(10)
for i in range(10):
  cuadcm3_100[i]=(cm3_100[i]-cm3_prom[6])**(2)
  varcm3_100=(1/len(cm3_100))*sum(cuadcm3_100)
  desvcm3_100= (varcm3_100)**(1/2)
print('la varianza del centro de masa, al rededor de 100 segundos',varcm3_100)
print('la desviación estándar del centro de masa, alrededor de 100 segundos',desvcm3_100)
# Out:
# Para 150 partículas
# la varianza del tiempo medido alrededor de 5 segundos 0.05452899999999997
# la desviación estándar del tiempo medido alrededor de 5 segundos 0.23351445351412398
# la varianza del tiempo medido alrededor de 10 segundos 0.054176000000000016
# la desviación estándar del tiempo medido alrededor de 10 segundos 0.23275738441561852
# la varianza del tiempo medido al rededor de 20 segundos 0.00900099999999994
# la desviación estándar del tiempo medido alrededor de 20 segundos 0.0948736001214244
# la varianza del tiempo medido alrededor de 30 segundos 0.007064999999999985
# la desviación estándar del tiempo medido alrededor de 30 segundos 0.08405355435673131
# la varianza del tiempo medido alrededor de 50 segundos 0.009343999999999955
# la desviación estándar del tiempo medido alrededor de 50 segundos 0.09666436778875634
# la varianza del tiempo medido alrededor de 80 segundos 0.05998499999999915
# ...

# %%
#Varianza y desviación estandar para 200 partículas
print('Para 200 partículas')

t4_5=t4[0]  #tiempo 5 s
cuadt4_5=np.zeros(10)
for i in range(10):
  cuadt4_5[i]=(t4_5[i]-t4_prom[0])**(2)
  vart4_5=(1/len(t4_5))*sum(cuadt4_5)
  desvt4_5= (vart4_5)**(1/2)
print('la varianza del tiempo medido alrededor de 5 segundos', vart4_5)      
print('la desviación estándar del tiempo medido alrededor de 5 segundos',desvt4_5)

t4_10=t4[1]  #tiempo 10 s 
cuadt4_10=np.zeros(10)
for i in range(10):
  cuadt4_10[i]=(t4_10[i]-t4_prom[1])**(2)
  vart4_10=(1/len(t4_10))*sum(cuadt4_10)
  desvt4_10= (vart4_10)**(1/2)
print('la varianza del tiempo medido alrededor de 10 segundos',vart4_10)
print('la desviación estándar del tiempo medido alrededor de 10 segundos',desvt4_10)

t4_20=t4[2]  #tiempo 20 s 
cuadt4_20=np.zeros(10)
for i in range(10):
  cuadt4_20[i]=(t4_20[i]-t4_prom[2])**(2)
  vart4_20=(1/len(t4_20))*sum(cuadt4_20)
  desvt4_20= (vart3_20)**(1/2)
print('la varianza del tiempo medido al rededor de 20 segundos',vart4_20)
print('la desviación estándar del tiempo medido alrededor de 20 segundos',desvt4_20)

t4_30=t4[3]  #tiempo 30 s 
cuadt4_30=np.zeros(10)
for i in range(10):
  cuadt4_30[i]=(t4_30[i]-t4_prom[3])**(2)
  vart4_30=(1/len(t4_30))*sum(cuadt4_30)
  desvt4_30= (vart4_30)**(1/2)
print('la varianza del tiempo medido alrededor de 30 segundos',vart4_30)
print('la desviación estándar del tiempo medido alrededor de 30 segundos',desvt4_30)

t4_50=t4[4]  #tiempo 50 s 
cuadt4_50=np.zeros(10)
for i in range(10):
  cuadt4_50[i]=(t4_50[i]-t4_prom[4])**(2)
  vart4_50=(1/len(t4_50))*sum(cuadt4_50)
  desvt4_50= (vart4_50)**(1/2)
print('la varianza del tiempo medido alrededor de 50 segundos',vart4_50)
print('la desviación estándar del tiempo medido alrededor de 50 segundos',desvt4_50)

t4_80=t4[5]  #tiempo 80 s 
cuadt4_80=np.zeros(10)
for i in range(10):
  cuadt4_80[i]=(t4_80[i]-t4_prom[5])**(2)
  vart4_80=(1/len(t4_80))*sum(cuadt4_80)
  desvt4_80= (vart4_80)**(1/2)
print('la varianza del tiempo medido alrededor de 80 segundos',vart4_80)
print('la desviación estándar del tiempo medido alrededor de 50 segundos',desvt4_80)

t4_100=t4[6]  #tiempo 100 s 
cuadt4_100=np.zeros(10)
for i in range(10):
  cuadt4_100[i]=(t4_100[i]-t4_prom[6])**(2)
  vart4_100=(1/len(t4_100))*sum(cuadt4_100)
  desvt4_100= (vart4_100)**(1/2)
print('la varianza del tiempo medido alrededor de 100 segundos',vart4_100)
print('la desviación estándar del tiempo medido alrededor de 100 segundos',desvt4_100)

n4_5=n4[0]  #numero de particulas en el intervalo 5 s
cuadn4_5=np.zeros(10)
for i in range(10):
  cuadn4_5[i]=(n4_5[i]-n4_prom[0])**(2)
  varn4_5=(1/len(n4_5))*sum(cuadn4_5)
  desvn4_5= (varn4_5)**(1/2)
print('la varianza del número de partículas, alrededor de 5 segundos',varn4_5)
print('la desviación estándar del número de partículas, alrededor de 5 segundos',desvn4_5)

n4_10=n4[1]  #numero de particulas en el intervalo 10 s
cuadn4_10=np.zeros(10)
for i in range(10):
  cuadn4_10[i]=(n4_10[i]-n4_prom[1])**(2)
  varn4_10=(1/len(n4_10))*sum(cuadn4_10)
  desvn4_10= (varn4_10)**(1/2)
print('la varianza del número de partículas, alrededor de 10 segundos', varn4_10)
print('la desviación estándar del número de partículas, alrededor de 10 segundos',desvn4_10)

n4_20=n4[2]  #numero de particulas en el intervalo 20 s
cuadn4_20=np.zeros(10)
for i in range(10):
  cuadn4_20[i]=(n4_20[i]-n4_prom[2])**(2)
  varn4_20=(1/len(n4_20))*sum(cuadn4_20)
  desvn4_20= (varn4_20)**(1/2)
print('la varianza del número de partículas, alrededor de 20 segundos',varn4_20)
print('la desviación estándar del número de partículas, alrededor de 20 segundos',desvn4_20)

n4_30=n4[3]  #numero de particulas en el intervalo 30 s
cuadn4_30=np.zeros(10)
for i in range(10):
  cuadn4_30[i]=(n4_30[i]-n4_prom[3])**(2)
  varn4_30=(1/len(n4_30))*sum(cuadn4_30)
  desvn4_30= (varn4_30)**(1/2)
print('la varianza del número de partículas, alrededor de 30 segundos',varn4_30)
print('la desviación estándar del número de partículas, alrededor de 30 segundos',desvn4_30)

n4_50=n4[4]  #numero de particulas en el intervalo 50 s
cuadn4_50=np.zeros(10)
for i in range(10):
  cuadn4_50[i]=(n4_50[i]-n4_prom[4])**(2)
  varn4_50=(1/len(n4_50))*sum(cuadn4_50)
  desvn4_50= (varn4_50)**(1/2)
print('la varianza del número de partículas, alrededor de 50 segundos',varn4_50)
print('la desviación estándar del número de partículas, alrededor de 50 segundos',desvn4_50)

n4_80=n4[5]  #numero de particulas en el intervalo 50 s
cuadn4_80=np.zeros(10)
for i in range(10):
  cuadn4_80[i]=(n4_80[i]-n4_prom[5])**(2)
  varn4_80=(1/len(n4_80))*sum(cuadn4_80)
  desvn4_80= (varn4_80)**(1/2)
print('la varianza del número de partículas, alrededor de 80 segundos',varn4_80)
print('la desviación estándar del número de partículas, alrededor de 80 segundos',desvn4_80)

n4_100=n4[6]  #numero de particulas en el intervalo 100 s
cuadn4_100=np.zeros(10)
for i in range(10):
  cuadn4_100[i]=(n4_100[i]-n4_prom[6])**(2)
  varn4_100=(1/len(n4_100))*sum(cuadn4_100)
  desvn4_100= (varn4_100)**(1/2)
print('la varianza del número de partículas, alrededor de 100 segundos',varn4_100)
print('la desviación estándar del número de partículas, alrededor de 100 segundos',desvn4_100)

cm4_5=cm4[0]  #centro de masa en el intervalo 5 s
cuadcm4_5=np.zeros(10)
for i in range(10):
  cuadcm4_5[i]=(cm4_5[i]-cm4_prom[0])**(2)
  varcm4_5=(1/len(cm4_5))*sum(cuadcm4_5)
  desvcm4_5= (varcm4_5)**(1/2)
print('la varianza del centro de masa, alrededor de 5 segundos',varcm4_5)
print('la desviación estándar del centro de masa, alrededor de 5 segundos', desvcm4_5)

cm4_10=cm3[1]  #centro de masa en el intervalo 10 s
cuadcm4_10=np.zeros(10)
for i in range(10):
  cuadcm4_10[i]=(cm4_10[i]-cm4_prom[1])**(2)
  varcm4_10=(1/len(cm4_10))*sum(cuadcm4_10)
  desvcm4_10= (varcm4_10)**(1/2)
print('la varianza del centro de masa, al rededor de 10 segundos',varcm4_10)
print('la desviación estándar del centro de masa, alrededor de 10 segundos',desvcm4_10)

cm4_20=cm4[2]  #centro de masa en el intervalo 20 s
cuadcm4_20=np.zeros(10)
for i in range(10):
  cuadcm4_20[i]=(cm4_20[i]-cm4_prom[2])**(2)
  varcm4_20=(1/len(cm4_20))*sum(cuadcm4_20)
  desvcm4_20= (varcm4_20)**(1/2)
print('la varianza del centro de masa, al rededor de 20 segundos',varcm4_20)
print('la desviación estándar del centro de masa, alrededor de 20 segundos',desvcm4_20)

cm4_30=cm4[3]  #centro de masa en el intervalo 30 s
cuadcm4_30=np.zeros(10)
for i in range(10):
  cuadcm4_30[i]=(cm4_30[i]-cm4_prom[3])**(2)
  varcm4_30=(1/len(cm4_30))*sum(cuadcm4_30)
  desvcm4_30= (varcm3_30)**(1/2)
print('la varianza del centro de masa, al rededor de 30 segundos',varcm4_30)
print('la desviación estándar del centro de masa, alrededor de 30 segundos', desvcm4_30)

cm4_50=cm4[4]  #centro de masa en el intervalo 50 s
cuadcm4_50=np.zeros(10)
for i in range(10):
  cuadcm4_50[i]=(cm4_50[i]-cm4_prom[4])**(2)
  varcm4_50=(1/len(cm4_50))*sum(cuadcm4_50)
  desvcm4_50= (varcm4_50)**(1/2)
print('la varianza del centro de masa, al rededor de 50 segundos',varcm3_50)
print('la desviación estándar del centro de masa, alrededor de 50 segundos',desvcm3_50)

cm4_80=cm4[5]  #centro de masa en el intervalo 80 s
cuadcm4_80=np.zeros(10)
for i in range(10):
  cuadcm4_80[i]=(cm4_80[i]-cm4_prom[6])**(2)
  varcm4_80=(1/len(cm4_80))*sum(cuadcm4_80)
  desvcm4_80= (varcm4_80)**(1/2)
print('la varianza del centro de masa, al rededor de 80 segundos',varcm4_80)
print('la desviación estándar del centro de masa, alrededor de 80 segundos',desvcm4_80)

cm4_100=cm4[6]  #centro de masa en el intervalo 100 s
cuadcm4_100=np.zeros(10)
for i in range(10):
  cuadcm4_100[i]=(cm4_100[i]-cm4_prom[6])**(2)
  varcm4_100=(1/len(cm4_100))*sum(cuadcm4_100)
  desvcm4_100= (varcm4_100)**(1/2)
print('la varianza del centro de masa, al rededor de 100 segundos',varcm4_100)
print('la desviación estándar del centro de masa, alrededor de 100 segundos',desvcm4_100)
# Out:
# Para 200 partículas
# la varianza del tiempo medido alrededor de 5 segundos 0.05452899999999997
# la desviación estándar del tiempo medido alrededor de 5 segundos 0.23351445351412398
# la varianza del tiempo medido alrededor de 10 segundos 0.024841000000000057
# la desviación estándar del tiempo medido alrededor de 10 segundos 0.15761027885261816
# la varianza del tiempo medido al rededor de 20 segundos 0.006815999999999968
# la desviación estándar del tiempo medido alrededor de 20 segundos 0.0948736001214244
# la varianza del tiempo medido alrededor de 30 segundos 0.11212399999999981
# la desviación estándar del tiempo medido alrededor de 30 segundos 0.3348492197990012
# la varianza del tiempo medido alrededor de 50 segundos 0.013055999999999872
# la desviación estándar del tiempo medido alrededor de 50 segundos 0.11426285485668504
# la varianza del tiempo medido alrededor de 80 segundos 0.034861000000001134
# ...

# %%
#error absoluto y relativo para 50 partículas
print('Para 50 partículas')
errabst1_5=np.zeros(10) #error absoluto para el tiempo 5 s
errrelt1_5=np.zeros(10) #error absoluto para el tiempo 5 s
for i in range(10):
  errabst1_5[i]= t1_prom[0]-t1_5[i]
  errrelt1_5[i]= (1/(t1_prom[0]))*errabst1_5[i]
print('El error relativo de cada medida del tiempo alrededor de 5 segundos',errrelt1_5)
print('El error porcentual de cada medida del tiempo alrededor de 5 segundos',abs(errrelt1_5*100))

errabst1_10=np.zeros(10) #error absoluto para el tiempo 10 s
errrelt1_10=np.zeros(10) #error absoluto para el tiempo 10 s
for i in range(10):
  errabst1_10[i]= t1_prom[1]-t1_10[i]
  errrelt1_10[i]= (1/(t1_prom[1]))*errabst1_10[i]
print('El error relativo de cada medida del tiempo alrededor de 10 segundos',errrelt1_10)
print('El error porcentual de cada medida del tiempo alrededor de 10 segundos',abs(errrelt1_10*100))

errabst1_20=np.zeros(10) #error absoluto para el tiempo 20 s
errrelt1_20=np.zeros(10) #error absoluto para el tiempo 20 s
for i in range(10):
  errabst1_20[i]= t1_prom[2]-t1_20[i]
  errrelt1_20[i]= (1/(t1_prom[2]))*errabst1_20[i]
print('El error relativo de cada medida del tiempo alrededor de 20 segundos',errrelt1_20)
print('El error porcentual de cada medida del tiempo alrededor de 20 segundos',abs(errrelt1_20*100))

errabst1_30=np.zeros(10) #error absoluto para el tiempo 30 s
errrelt1_30=np.zeros(10) #error absoluto para el tiempo 30 s
for i in range(10):
  errabst1_30[i]= t1_prom[3]-t1_30[i]
  errrelt1_30[i]= (1/(t1_prom[3]))*errabst1_30[i]
print('El error relativo de cada medida del tiempop alrededor de 30 segundos',errrelt1_30)
print('El error porcentual de cada medida del tiempo alrededor de 30 segundos',abs(errrelt1_30*100))

errabst1_50=np.zeros(10) #error absoluto para el tiempo 50 s
errrelt1_50=np.zeros(10) #error absoluto para el tiempo 50 s
for i in range(10):
  errabst1_50[i]= t1_prom[4]-t1_50[i]
  errrelt1_50[i]= (1/(t1_prom[4]))*errabst1_50[i]
print('El error relativo de cada medida del tiempo alrededor de 50 segundos',errrelt1_50)
print('El error porcentual de cada medida del tiempo alrededor de 50 segundos',abs(errrelt1_50*100))

errabst1_80=np.zeros(10) #error absoluto para el tiempo 80 s
errrelt1_80=np.zeros(10) #error absoluto para el tiempo 80 s
for i in range(10):
  errabst1_80[i]= t1_prom[5]-t1_80[i]
  errrelt1_80[i]= (1/(t1_prom[5]))*errabst1_80[i]
print('El error relativo del  cada medida del tiempo alrededor de 5 segundos',errrelt1_80)
print('El error porcentual de cada medida alrededor del tiempo de 5 segundos',abs(errrelt1_80*100))

errabst1_100=np.zeros(10) #error absoluto para el tiempo 100 s
errrelt1_100=np.zeros(10) #error absoluto para el tiempo 100 s
for i in range(10):
  errabst1_100[i]= t1_prom[6]-t1_100[i]
  errrelt1_100[i]= (1/(t1_prom[6]))*errabst1_100[i]
print('El error relativo de cada medida del tiempo alrededor de 5 segundos',errrelt1_100)
print('El error porcentual de cada medida del tiempo  alrededor de 5 segundos',abs(errrelt1_100*100))
###############################################################################

errabsn1_5=np.zeros(10) #error absoluto del número de partículas en el tiempo 5 s
errreln1_5=np.zeros(10) #error absoluto del número de partículas el tiempo 5 s
for i in range(10):
  errabsn1_5[i]= n1_prom[0]-n1_5[i]
  errreln1_5[i]= (1/(n1_prom[0]))*errabsn1_5[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln1_5)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln1_5*100))


errabsn1_10=np.zeros(10) #error absoluto del número de partículas en el tiempo 10 s
errreln1_10=np.zeros(10) #error absoluto del número de partículas el tiempo 10 s
for i in range(10):
  errabsn1_10[i]= n1_prom[1]-n1_10[i]
  errreln1_10[i]= (1/(n1_prom[1]))*errabsn1_10[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln1_10)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln1_10*100))


errabsn1_20=np.zeros(10) #error absoluto del número de partículas en el tiempo 20 s
errreln1_20=np.zeros(10) #error absoluto del número de partículas el tiempo 20 s
for i in range(10):
  errabsn1_20[i]= n1_prom[2]-n1_20[i]
  errreln1_20[i]= (1/(n1_prom[2]))*errabsn1_20[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln1_20)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln1_20*100))

errabsn1_30=np.zeros(10) #error absoluto del número de partículas en el tiempo 30 s
errreln1_30=np.zeros(10) #error absoluto del número de partículas el tiempo 30 s
for i in range(10):
  errabsn1_30[i]= n1_prom[3]-n1_30[i]
  errreln1_30[i]= (1/(n1_prom[3]))*errabsn1_30[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln1_30)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln1_30*100))

errabsn1_50=np.zeros(10) #error absoluto del número de partículas en el tiempo 50 s
errreln1_50=np.zeros(10) #error absoluto del número de partículas el tiempo 50 s
for i in range(10):
  errabsn1_50[i]= n1_prom[4]-n1_50[i]
  errreln1_50[i]= (1/(n1_prom[4]))*errabsn1_50[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln1_50)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln1_50*100))

errabsn1_80=np.zeros(10) #error absoluto del número de partículas en el tiempo 80 s
errreln1_80=np.zeros(10) #error absoluto del número de partículas el tiempo 80 s
for i in range(10):
  errabsn1_80[i]= n1_prom[5]-n1_80[i]
  errreln1_80[i]= (1/(n1_prom[5]))*errabsn1_80[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln1_80)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln1_80*100))

errabsn1_100=np.zeros(10) #error absoluto del número de partículas en el tiempo 100 s
errreln1_100=np.zeros(10) #error absoluto del número de partículas el tiempo 100 s
for i in range(10):
  errabsn1_100[i]= n1_prom[6]-n1_100[i]
  errreln1_100[i]= (1/(n1_prom[6]))*errabsn1_100[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln1_100)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln1_100*100))
###############################################################################

errabscm1_5=np.zeros(10) #error absoluto del centro de masa en el tiempo 5 s
errrelcm1_5=np.zeros(10) #error absoluto del centro de masa el tiempo 5 s
for i in range(10):
  errabscm1_5[i]= cm1_prom[0]-cm1_5[i]
  errrelcm1_5[i]= (1/(cm1_prom[0]))*errabscm1_5[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm1_5)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm1_5*100))

errabscm1_10=np.zeros(10) #error absoluto del centro de masa en el tiempo 10 s
errrelcm1_10=np.zeros(10) #error absoluto del centro de masa el tiempo 10 s
for i in range(10):
  errabscm1_10[i]= cm1_prom[1]-cm1_10[i]
  errrelcm1_10[i]= (1/(cm1_prom[1]))*errabscm1_10[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm1_10)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm1_10*100))

errabscm1_20=np.zeros(10) #error absoluto del centro de masa en el tiempo 20 s
errrelcm1_20=np.zeros(10) #error absoluto del centro de masa el tiempo 20 s
for i in range(10):
  errabscm1_20[i]= cm1_prom[2]-cm1_20[i]
  errrelcm1_20[i]= (1/(cm1_prom[2]))*errabscm1_20[i]
print('El error relativo de cada medida del centro de masa alrededor de 20 segundos',errrelcm1_20)
print('El error porcentual de cada medida del centro de masa alrededor de 20 segundos',abs(errrelcm1_20*100))

errabscm1_30=np.zeros(10) #error absoluto del centro de masa en el tiempo 30 s
errrelcm1_30=np.zeros(10) #error absoluto del centro de masa el tiempo 30 s
for i in range(10):
  errabscm1_30[i]= cm1_prom[3]-cm1_30[i]
  errrelcm1_30[i]= (1/(cm1_prom[3]))*errabscm1_30[i]
print('El error relativo de cada medida del centro de masa alrededor de 30 segundos',errrelcm1_30)
print('El error porcentual de cada medida del centro de masa alrededor de 30 segundos',abs(errrelcm1_30*100))


errabscm1_50=np.zeros(10) #error absoluto del centro de masa en el tiempo 50s
errrelcm1_50=np.zeros(10) #error absoluto del centro de masa el tiempo 50s
for i in range(10):
  errabscm1_50[i]= cm1_prom[4]-cm1_50[i]
  errrelcm1_50[i]= (1/(cm1_prom[4]))*errabscm1_50[i]
print('El error relativo de cada medida del centro de masa alrededor de 50 segundos',errrelcm1_50)
print('El error porcentual de cada medida del centro de masa alrededor de 50 segundos',abs(errrelcm1_50*100))

errabscm1_80=np.zeros(10) #error absoluto del centro de masa en el tiempo 80s
errrelcm1_80=np.zeros(10) #error absoluto del centro de masa el tiempo 80s
for i in range(10):
  errabscm1_80[i]= cm1_prom[5]-cm1_80[i]
  errrelcm1_80[i]= (1/(cm1_prom[5]))*errabscm1_80[i]
print('El error relativo de cada medida del centro de masa alrededor de 80 segundos',errrelcm1_80)
print('El error porcentual de cada medida del centro de masa alrededor de 80 segundos',abs(errrelcm1_80*100))

errabscm1_100=np.zeros(10) #error absoluto del centro de masa en el tiempo 100s
errrelcm1_100=np.zeros(10) #error absoluto del centro de masa el tiempo 100s
for i in range(10):
  errabscm1_100[i]= cm1_prom[6]-cm1_100[i]
  errrelcm1_100[i]= (1/(cm1_prom[6]))*errabscm1_100[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm1_100)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm1_100*100))
# Out:
# Para 50 partículas
# El error relativo de cada medida del tiempo alrededor de 5 segundos [-0.01579721  0.05951506  0.01542983 -0.03049229  0.02094048 -0.09294636
#  -0.02314475  0.04481999 -0.01579721  0.03747245]
# El error porcentual de cada medida del tiempo alrededor de 5 segundos [1.57972079 5.95150625 1.5429831  3.04922851 2.09404849 9.2946363
#  2.31447465 4.48199853 1.57972079 3.74724467]
# El error relativo de cada medida del tiempo alrededor de 10 segundos [-0.01380249  0.01827372 -0.00213841 -0.00213841 -0.00311042  0.00563764
#   0.00660964 -0.01769051 -0.00213841  0.01049767]
# El error porcentual de cada medida del tiempo alrededor de 10 segundos [1.38024883 1.8273717  0.21384137 0.21384137 0.31104199 0.56376361
#  0.66096423 1.76905132 0.21384137 1.04976672]
# El error relativo de cada medida del tiempo alrededor de 20 segundos [ 0.00069088  0.00069088  0.00315831  0.00069088 -0.00572444 -0.00128306
#  -0.00078958  0.0071062   0.00266482 -0.0072049 ]
# ...

# %%
#error absoluto y relativo para 100 partículas
print('Para 100 partículas')
errabst2_5=np.zeros(10) #error absoluto para el tiempo 5 s
errrelt2_5=np.zeros(10) #error absoluto para el tiempo 5 s
for i in range(10):
  errabst2_5[i]= t2_prom[0]-t2_5[i]
  errrelt2_5[i]= (1/(t2_prom[0]))*errabst2_5[i]
print('El error relativo de cada medida del tiempo alrededor de 5 segundos',errrelt2_5)
print('El error porcentual de cada medida del tiempo alrededor de 5 segundos',abs(errrelt2_5*100))

errabst2_10=np.zeros(10) #error absoluto para el tiempo 10 s
errrelt2_10=np.zeros(10) #error absoluto para el tiempo 10 s
for i in range(10):
  errabst2_10[i]= t2_prom[1]-t2_10[i]
  errrelt2_10[i]= (1/(t2_prom[1]))*errabst2_10[i]
print('El error relativo de cada medida del tiempo alrededor de 10 segundos',errrelt2_10)
print('El error porcentual de cada medida del tiempo alrededor de 10 segundos',abs(errrelt2_10*100))

errabst2_20=np.zeros(10) #error absoluto para el tiempo 20 s
errrelt2_20=np.zeros(10) #error absoluto para el tiempo 20 s
for i in range(10):
  errabst2_20[i]= t2_prom[2]-t2_20[i]
  errrelt2_20[i]= (1/(t2_prom[2]))*errabst2_20[i]
print('El error relativo de cada medida del tiempo alrededor de 20 segundos',errrelt2_20)
print('El error porcentual de cada medida del tiempo alrededor de 20 segundos',abs(errrelt2_20*100))

errabst2_30=np.zeros(10) #error absoluto para el tiempo 30 s
errrelt2_30=np.zeros(10) #error absoluto para el tiempo 30 s
for i in range(10):
  errabst2_30[i]= t2_prom[3]-t2_30[i]
  errrelt2_30[i]= (1/(t2_prom[3]))*errabst2_30[i]
print('El error relativo de cada medida del tiempop alrededor de 30 segundos',errrelt2_30)
print('El error porcentual de cada medida del tiempo alrededor de 30 segundos',abs(errrelt2_30*100))

errabst2_50=np.zeros(10) #error absoluto para el tiempo 50 s
errrelt2_50=np.zeros(10) #error absoluto para el tiempo 50 s
for i in range(10):
  errabst1_50[i]= t2_prom[4]-t2_50[i]
  errrelt1_50[i]= (1/(t1_prom[4]))*errabst1_50[i]
print('El error relativo de cada medida del tiempo alrededor de 50 segundos',errrelt2_50)
print('El error porcentual de cada medida del tiempo alrededor de 50 segundos',abs(errrelt2_50*100))

errabst2_80=np.zeros(10) #error absoluto para el tiempo 80 s
errrelt2_80=np.zeros(10) #error absoluto para el tiempo 80 s
for i in range(10):
  errabst2_80[i]= t2_prom[5]-t2_80[i]
  errrelt2_80[i]= (1/(t2_prom[5]))*errabst2_80[i]
print('El error relativo del  cada medida del tiempo alrededor de 5 segundos',errrelt2_80)
print('El error porcentual de cada medida alrededor del tiempo de 5 segundos',abs(errrelt2_80*100))

errabst2_100=np.zeros(10) #error absoluto para el tiempo 100 s
errrelt2_100=np.zeros(10) #error absoluto para el tiempo 100 s
for i in range(10):
  errabst2_100[i]= t2_prom[6]-t2_100[i]
  errrelt2_100[i]= (1/(t2_prom[6]))*errabst2_100[i]
print('El error relativo de cada medida del tiempo alrededor de 5 segundos',errrelt2_100)
print('El error porcentual de cada medida del tiempo  alrededor de 5 segundos',abs(errrelt2_100*100))
###############################################################################

errabsn2_5=np.zeros(10) #error absoluto del número de partículas en el tiempo 5 s
errreln2_5=np.zeros(10) #error absoluto del número de partículas el tiempo 5 s
for i in range(10):
  errabsn2_5[i]= n2_prom[0]-n2_5[i]
  errreln2_5[i]= (1/(n2_prom[0]))*errabsn2_5[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln2_5)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln2_5*100))


errabsn2_10=np.zeros(10) #error absoluto del número de partículas en el tiempo 10 s
errreln2_10=np.zeros(10) #error absoluto del número de partículas el tiempo 10 s
for i in range(10):
  errabsn2_10[i]= n2_prom[1]-n2_10[i]
  errreln2_10[i]= (1/(n2_prom[1]))*errabsn2_10[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln2_10)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln2_10*100))


errabsn2_20=np.zeros(10) #error absoluto del número de partículas en el tiempo 20 s
errreln2_20=np.zeros(10) #error absoluto del número de partículas el tiempo 20 s
for i in range(10):
  errabsn2_20[i]= n2_prom[2]-n2_20[i]
  errreln2_20[i]= (1/(n2_prom[2]))*errabsn2_20[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln2_20)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln2_20*100))

errabsn2_30=np.zeros(10) #error absoluto del número de partículas en el tiempo 30 s
errreln2_30=np.zeros(10) #error absoluto del número de partículas el tiempo 30 s
for i in range(10):
  errabsn2_30[i]= n2_prom[3]-n2_30[i]
  errreln2_30[i]= (1/(n2_prom[3]))*errabsn2_30[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln2_30)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln2_30*100))

errabsn2_50=np.zeros(10) #error absoluto del número de partículas en el tiempo 50 s
errreln2_50=np.zeros(10) #error absoluto del número de partículas el tiempo 50 s
for i in range(10):
  errabsn2_50[i]= n2_prom[4]-n2_50[i]
  errreln2_50[i]= (1/(n2_prom[4]))*errabsn2_50[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln2_50)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln2_50*100))

errabsn2_80=np.zeros(10) #error absoluto del número de partículas en el tiempo 80 s
errreln2_80=np.zeros(10) #error absoluto del número de partículas el tiempo 80 s
for i in range(10):
  errabsn2_80[i]= n2_prom[5]-n2_80[i]
  errreln2_80[i]= (1/(n2_prom[5]))*errabsn2_80[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln2_80)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln2_80*100))

errabsn2_100=np.zeros(10) #error absoluto del número de partículas en el tiempo 100 s
errreln2_100=np.zeros(10) #error absoluto del número de partículas el tiempo 100 s
for i in range(10):
  errabsn2_100[i]= n2_prom[6]-n2_100[i]
  errreln2_100[i]= (1/(n2_prom[6]))*errabsn2_100[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln2_100)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln2_100*100))
###############################################################################

errabscm2_5=np.zeros(10) #error absoluto del centro de masa en el tiempo 5 s
errrelcm2_5=np.zeros(10) #error absoluto del centro de masa el tiempo 5 s
for i in range(10):
  errabscm2_5[i]= cm2_prom[0]-cm2_5[i]
  errrelcm2_5[i]= (1/(cm2_prom[0]))*errabscm2_5[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm2_5)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm2_5*100))

errabscm2_10=np.zeros(10) #error absoluto del centro de masa en el tiempo 10 s
errrelcm2_10=np.zeros(10) #error absoluto del centro de masa el tiempo 10 s
for i in range(10):
  errabscm2_10[i]= cm2_prom[1]-cm2_10[i]
  errrelcm2_10[i]= (1/(cm2_prom[1]))*errabscm2_10[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm2_10)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm2_10*100))

errabscm2_20=np.zeros(10) #error absoluto del centro de masa en el tiempo 20 s
errrelcm2_20=np.zeros(10) #error absoluto del centro de masa el tiempo 20 s
for i in range(10):
  errabscm2_20[i]= cm2_prom[2]-cm2_20[i]
  errrelcm2_20[i]= (1/(cm2_prom[2]))*errabscm2_20[i]
print('El error relativo de cada medida del centro de masa alrededor de 20 segundos',errrelcm2_20)
print('El error porcentual de cada medida del centro de masa alrededor de 20 segundos',abs(errrelcm2_20*100))

errabscm2_30=np.zeros(10) #error absoluto del centro de masa en el tiempo 30 s
errrelcm2_30=np.zeros(10) #error absoluto del centro de masa el tiempo 30 s
for i in range(10):
  errabscm2_30[i]= cm2_prom[3]-cm2_30[i]
  errrelcm2_30[i]= (1/(cm2_prom[3]))*errabscm2_30[i]
print('El error relativo de cada medida del centro de masa alrededor de 30 segundos',errrelcm2_30)
print('El error porcentual de cada medida del centro de masa alrededor de 30 segundos',abs(errrelcm2_30*100))


errabscm2_50=np.zeros(10) #error absoluto del centro de masa en el tiempo 50s
errrelcm2_50=np.zeros(10) #error absoluto del centro de masa el tiempo 50s
for i in range(10):
  errabscm2_50[i]= cm2_prom[4]-cm2_50[i]
  errrelcm2_50[i]= (1/(cm2_prom[4]))*errabscm2_50[i]
print('El error relativo de cada medida del centro de masa alrededor de 50 segundos',errrelcm2_50)
print('El error porcentual de cada medida del centro de masa alrededor de 50 segundos',abs(errrelcm2_50*100))

errabscm2_80=np.zeros(10) #error absoluto del centro de masa en el tiempo 80s
errrelcm2_80=np.zeros(10) #error absoluto del centro de masa el tiempo 80s
for i in range(10):
  errabscm2_80[i]= cm2_prom[5]-cm2_80[i]
  errrelcm2_80[i]= (1/(cm2_prom[5]))*errabscm2_80[i]
print('El error relativo de cada medida del centro de masa alrededor de 80 segundos',errrelcm2_80)
print('El error porcentual de cada medida del centro de masa alrededor de 80 segundos',abs(errrelcm2_80*100))

errabscm2_100=np.zeros(10) #error absoluto del centro de masa en el tiempo 100s
errrelcm2_100=np.zeros(10) #error absoluto del centro de masa el tiempo 100s
for i in range(10):
  errabscm2_100[i]= cm2_prom[6]-cm2_100[i]
  errrelcm2_100[i]= (1/(cm2_prom[6]))*errabscm2_100[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm2_100)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm2_100*100))
# Out:
# Para 100 partículas
# El error relativo de cada medida del tiempo alrededor de 5 segundos [-0.04072398 -0.06425339  0.07873303 -0.01900452  0.00271493 -0.02624434
#   0.03710407 -0.04977376  0.05520362  0.02624434]
# El error porcentual de cada medida del tiempo alrededor de 5 segundos [4.07239819 6.42533937 7.87330317 1.90045249 0.27149321 2.62443439
#  3.71040724 4.97737557 5.52036199 2.62443439]
# El error relativo de cada medida del tiempo alrededor de 10 segundos [-0.03097968 -0.03198552 -0.02796218  0.03942869  0.00523034  0.02333535
#  -0.00985717  0.00925367  0.01830618  0.00523034]
# El error porcentual de cada medida del tiempo alrededor de 10 segundos [3.09796822 3.1985516  2.79621806 3.94286864 0.52303359 2.3335345
#  0.98571716 0.92536713 1.83061758 0.52303359]
# El error relativo de cada medida del tiempo alrededor de 20 segundos [-0.00750375  0.00250125  0.00050025  0.00450225 -0.00350175 -0.02401201
#   0.014007    0.00050025  0.02101051 -0.008004  ]
# ...

# %%
#error absoluto y relativo para 150 partículas
print('Para 150 partículas')
errabst3_5=np.zeros(10) #error absoluto para el tiempo 5 s
errrelt3_5=np.zeros(10) #error absoluto para el tiempo 5 s
for i in range(10):
  errabst3_5[i]= t3_prom[0]-t3_5[i]
  errrelt3_5[i]= (1/(t3_prom[0]))*errabst3_5[i]
print('El error relativo de cada medida del tiempo alrededor de 5 segundos',errrelt3_5)
print('El error porcentual de cada medida del tiempo alrededor de 5 segundos',abs(errrelt3_5*100))

errabst3_10=np.zeros(10) #error absoluto para el tiempo 10 s
errrelt3_10=np.zeros(10) #error absoluto para el tiempo 10 s
for i in range(10):
  errabst3_10[i]= t3_prom[1]-t3_10[i]
  errrelt3_10[i]= (1/(t3_prom[1]))*errabst3_10[i]
print('El error relativo de cada medida del tiempo alrededor de 10 segundos',errrelt3_10)
print('El error porcentual de cada medida del tiempo alrededor de 10 segundos',abs(errrelt3_10*100))

errabst3_20=np.zeros(10) #error absoluto para el tiempo 20 s
errrelt3_20=np.zeros(10) #error absoluto para el tiempo 20 s
for i in range(10):
  errabst3_20[i]= t3_prom[2]-t3_20[i]
  errrelt3_20[i]= (1/(t3_prom[2]))*errabst3_20[i]
print('El error relativo de cada medida del tiempo alrededor de 20 segundos',errrelt3_20)
print('El error porcentual de cada medida del tiempo alrededor de 20 segundos',abs(errrelt3_20*100))

errabst3_30=np.zeros(10) #error absoluto para el tiempo 30 s
errrelt3_30=np.zeros(10) #error absoluto para el tiempo 30 s
for i in range(10):
  errabst3_30[i]= t3_prom[3]-t3_30[i]
  errrelt3_30[i]= (1/(t3_prom[3]))*errabst3_30[i]
print('El error relativo de cada medida del tiempop alrededor de 30 segundos',errrelt3_30)
print('El error porcentual de cada medida del tiempo alrededor de 30 segundos',abs(errrelt3_30*100))

errabst3_50=np.zeros(10) #error absoluto para el tiempo 50 s
errrelt3_50=np.zeros(10) #error absoluto para el tiempo 50 s
for i in range(10):
  errabst3_50[i]= t3_prom[4]-t3_50[i]
  errrelt3_50[i]= (1/(t3_prom[4]))*errabst3_50[i]
print('El error relativo de cada medida del tiempo alrededor de 50 segundos',errrelt3_50)
print('El error porcentual de cada medida del tiempo alrededor de 50 segundos',abs(errrelt3_50*100))

errabst3_80=np.zeros(10) #error absoluto para el tiempo 80 s
errrelt3_80=np.zeros(10) #error absoluto para el tiempo 80 s
for i in range(10):
  errabst3_80[i]= t3_prom[5]-t3_80[i]
  errrelt3_80[i]= (1/(t3_prom[5]))*errabst3_80[i]
print('El error relativo del  cada medida del tiempo alrededor de 5 segundos',errrelt3_80)
print('El error porcentual de cada medida alrededor del tiempo de 5 segundos',abs(errrelt3_80*100))

errabst3_100=np.zeros(10) #error absoluto para el tiempo 100 s
errrelt3_100=np.zeros(10) #error absoluto para el tiempo 100 s
for i in range(10):
  errabst3_100[i]= t3_prom[6]-t3_100[i]
  errrelt3_100[i]= (1/(t3_prom[6]))*errabst3_100[i]
print('El error relativo de cada medida del tiempo alrededor de 5 segundos',errrelt3_100)
print('El error porcentual de cada medida del tiempo  alrededor de 5 segundos',abs(errrelt3_100*100))
###############################################################################

errabsn3_5=np.zeros(10) #error absoluto del número de partículas en el tiempo 5 s
errreln3_5=np.zeros(10) #error absoluto del número de partículas el tiempo 5 s
for i in range(10):
  errabsn3_5[i]= n3_prom[0]-n3_5[i]
  errreln3_5[i]= (1/(n3_prom[0]))*errabsn3_5[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln3_5)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln3_5*100))


errabsn3_10=np.zeros(10) #error absoluto del número de partículas en el tiempo 10 s
errreln3_10=np.zeros(10) #error absoluto del número de partículas el tiempo 10 s
for i in range(10):
  errabsn3_10[i]= n3_prom[1]-n3_10[i]
  errreln3_10[i]= (1/(n3_prom[1]))*errabsn3_10[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln3_10)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln3_10*100))


errabsn3_20=np.zeros(10) #error absoluto del número de partículas en el tiempo 20 s
errreln3_20=np.zeros(10) #error absoluto del número de partículas el tiempo 20 s
for i in range(10):
  errabsn3_20[i]= n3_prom[2]-n3_20[i]
  errreln3_20[i]= (1/(n3_prom[2]))*errabsn3_20[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln3_20)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln3_20*100))

errabsn3_30=np.zeros(10) #error absoluto del número de partículas en el tiempo 30 s
errreln3_30=np.zeros(10) #error absoluto del número de partículas el tiempo 30 s
for i in range(10):
  errabsn3_30[i]= n3_prom[3]-n3_30[i]
  errreln3_30[i]= (1/(n3_prom[3]))*errabsn3_30[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln3_30)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln3_30*100))

errabsn3_50=np.zeros(10) #error absoluto del número de partículas en el tiempo 50 s
errreln3_50=np.zeros(10) #error absoluto del número de partículas el tiempo 50 s
for i in range(10):
  errabsn3_50[i]= n3_prom[4]-n3_50[i]
  errreln3_50[i]= (1/(n3_prom[4]))*errabsn3_50[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln3_50)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln3_50*100))

errabsn3_80=np.zeros(10) #error absoluto del número de partículas en el tiempo 80 s
errreln3_80=np.zeros(10) #error absoluto del número de partículas el tiempo 80 s
for i in range(10):
  errabsn3_80[i]= n3_prom[5]-n3_80[i]
  errreln3_80[i]= (1/(n3_prom[5]))*errabsn3_80[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln3_80)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln3_80*100))

errabsn3_100=np.zeros(10) #error absoluto del número de partículas en el tiempo 100 s
errreln3_100=np.zeros(10) #error absoluto del número de partículas el tiempo 100 s
for i in range(10):
  errabsn3_100[i]= n3_prom[6]-n2_100[i]
  errreln3_100[i]= (1/(n3_prom[6]))*errabsn3_100[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln3_100)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln3_100*100))
###############################################################################

errabscm3_5=np.zeros(10) #error absoluto del centro de masa en el tiempo 5 s
errrelcm3_5=np.zeros(10) #error absoluto del centro de masa el tiempo 5 s
for i in range(10):
  errabscm3_5[i]= cm3_prom[0]-cm3_5[i]
  errrelcm3_5[i]= (1/(cm3_prom[0]))*errabscm3_5[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm3_5)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm3_5*100))

errabscm3_10=np.zeros(10) #error absoluto del centro de masa en el tiempo 10 s
errrelcm3_10=np.zeros(10) #error absoluto del centro de masa el tiempo 10 s
for i in range(10):
  errabscm3_10[i]= cm3_prom[1]-cm3_10[i]
  errrelcm3_10[i]= (1/(cm3_prom[1]))*errabscm3_10[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm3_10)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm3_10*100))

errabscm3_20=np.zeros(10) #error absoluto del centro de masa en el tiempo 20 s
errrelcm3_20=np.zeros(10) #error absoluto del centro de masa el tiempo 20 s
for i in range(10):
  errabscm3_20[i]= cm3_prom[2]-cm3_20[i]
  errrelcm3_20[i]= (1/(cm3_prom[2]))*errabscm3_20[i]
print('El error relativo de cada medida del centro de masa alrededor de 20 segundos',errrelcm3_20)
print('El error porcentual de cada medida del centro de masa alrededor de 20 segundos',abs(errrelcm3_20*100))

errabscm3_30=np.zeros(10) #error absoluto del centro de masa en el tiempo 30 s
errrelcm3_30=np.zeros(10) #error absoluto del centro de masa el tiempo 30 s
for i in range(10):
  errabscm3_30[i]= cm3_prom[3]-cm3_30[i]
  errrelcm3_30[i]= (1/(cm3_prom[3]))*errabscm3_30[i]
print('El error relativo de cada medida del centro de masa alrededor de 30 segundos',errrelcm3_30)
print('El error porcentual de cada medida del centro de masa alrededor de 30 segundos',abs(errrelcm3_30*100))


errabscm3_50=np.zeros(10) #error absoluto del centro de masa en el tiempo 50s
errrelcm3_50=np.zeros(10) #error absoluto del centro de masa el tiempo 50s
for i in range(10):
  errabscm3_50[i]= cm3_prom[4]-cm3_50[i]
  errrelcm3_50[i]= (1/(cm3_prom[4]))*errabscm3_50[i]
print('El error relativo de cada medida del centro de masa alrededor de 50 segundos',errrelcm3_50)
print('El error porcentual de cada medida del centro de masa alrededor de 50 segundos',abs(errrelcm3_50*100))

errabscm3_80=np.zeros(10) #error absoluto del centro de masa en el tiempo 80s
errrelcm3_80=np.zeros(10) #error absoluto del centro de masa el tiempo 80s
for i in range(10):
  errabscm3_80[i]= cm3_prom[5]-cm3_80[i]
  errrelcm3_80[i]= (1/(cm3_prom[5]))*errabscm3_80[i]
print('El error relativo de cada medida del centro de masa alrededor de 80 segundos',errrelcm3_80)
print('El error porcentual de cada medida del centro de masa alrededor de 80 segundos',abs(errrelcm3_80*100))

errabscm3_100=np.zeros(10) #error absoluto del centro de masa en el tiempo 100s
errrelcm3_100=np.zeros(10) #error absoluto del centro de masa el tiempo 100s
for i in range(10):
  errabscm3_100[i]= cm3_prom[6]-cm3_100[i]
  errrelcm3_100[i]= (1/(cm3_prom[6]))*errabscm3_100[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm3_100)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm3_100*100))
# Out:
# Para 150 partículas
# El error relativo de cada medida del tiempo alrededor de 5 segundos [-0.0577442  -0.00557654  0.05018888  0.03759669  0.01421119 -0.0577442
#   0.04839    -0.00017989 -0.05954308  0.03040115]
# El error porcentual de cada medida del tiempo alrededor de 5 segundos [5.77441986 0.55765425 5.01888829 3.75966901 1.42111891 5.77441986
#  4.83899982 0.01798885 5.95430833 3.04011513]
# El error relativo de cada medida del tiempo alrededor de 10 segundos [ 0.02324673  0.00859543  0.01250244 -0.03438172 -0.04903301  0.01152569
#   0.01250244  0.01054894  0.01640945 -0.01191639]
# El error porcentual de cada medida del tiempo alrededor de 10 segundos [2.32467279 0.85954288 1.25024419 3.43817152 4.90330143 1.15256886
#  1.25024419 1.05489353 1.6409455  1.19163899]
# El error relativo de cada medida del tiempo alrededor de 20 segundos [-0.0013371  -0.00282276  0.00262467 -0.00480364 -0.0013371   0.00658644
#   0.00014857 -0.00727975  0.00906255 -0.00084188]
# ...

# %%
#error absoluto y relativo para 200 partículas
print('Para 200 partículas')
errabst4_5=np.zeros(10) #error absoluto para el tiempo 5 s
errrelt4_5=np.zeros(10) #error absoluto para el tiempo 5 s
for i in range(10):
  errabst4_5[i]= t4_prom[0]-t4_5[i]
  errrelt4_5[i]= (1/(t4_prom[0]))*errabst4_5[i]
print('El error relativo de cada medida del tiempo alrededor de 5 segundos',errrelt4_5)
print('El error porcentual de cada medida del tiempo alrededor de 5 segundos',abs(errrelt4_5*100))

errabst4_10=np.zeros(10) #error absoluto para el tiempo 10 s
errrelt4_10=np.zeros(10) #error absoluto para el tiempo 10 s
for i in range(10):
  errabst4_10[i]= t4_prom[1]-t4_10[i]
  errrelt4_10[i]= (1/(t4_prom[1]))*errabst4_10[i]
print('El error relativo de cada medida del tiempo alrededor de 10 segundos',errrelt3_10)
print('El error porcentual de cada medida del tiempo alrededor de 10 segundos',abs(errrelt3_10*100))

errabst4_20=np.zeros(10) #error absoluto para el tiempo 20 s
errrelt4_20=np.zeros(10) #error absoluto para el tiempo 20 s
for i in range(10):
  errabst4_20[i]= t4_prom[2]-t4_20[i]
  errrelt4_20[i]= (1/(t4_prom[2]))*errabst4_20[i]
print('El error relativo de cada medida del tiempo alrededor de 20 segundos',errrelt4_20)
print('El error porcentual de cada medida del tiempo alrededor de 20 segundos',abs(errrelt4_20*100))

errabst4_30=np.zeros(10) #error absoluto para el tiempo 30 s
errrelt4_30=np.zeros(10) #error absoluto para el tiempo 30 s
for i in range(10):
  errabst4_30[i]= t4_prom[3]-t4_30[i]
  errrelt4_30[i]= (1/(t4_prom[3]))*errabst4_30[i]
print('El error relativo de cada medida del tiempop alrededor de 30 segundos',errrelt4_30)
print('El error porcentual de cada medida del tiempo alrededor de 30 segundos',abs(errrelt4_30*100))

errabst4_50=np.zeros(10) #error absoluto para el tiempo 50 s
errrelt4_50=np.zeros(10) #error absoluto para el tiempo 50 s
for i in range(10):
  errabst4_50[i]= t4_prom[4]-t4_50[i]
  errrelt4_50[i]= (1/(t4_prom[4]))*errabst4_50[i]
print('El error relativo de cada medida del tiempo alrededor de 50 segundos',errrelt4_50)
print('El error porcentual de cada medida del tiempo alrededor de 50 segundos',abs(errrelt4_50*100))

errabst4_80=np.zeros(10) #error absoluto para el tiempo 80 s
errrelt4_80=np.zeros(10) #error absoluto para el tiempo 80 s
for i in range(10):
  errabst4_80[i]= t4_prom[5]-t4_80[i]
  errrelt4_80[i]= (1/(t4_prom[5]))*errabst4_80[i]
print('El error relativo del  cada medida del tiempo alrededor de 5 segundos',errrelt4_80)
print('El error porcentual de cada medida alrededor del tiempo de 5 segundos',abs(errrelt4_80*100))

errabst4_100=np.zeros(10) #error absoluto para el tiempo 100 s
errrelt4_100=np.zeros(10) #error absoluto para el tiempo 100 s
for i in range(10):
  errabst4_100[i]= t4_prom[6]-t4_100[i]
  errrelt4_100[i]= (1/(t4_prom[6]))*errabst4_100[i]
print('El error relativo de cada medida del tiempo alrededor de 5 segundos',errrelt4_100)
print('El error porcentual de cada medida del tiempo  alrededor de 5 segundos',abs(errrelt4_100*100))
###############################################################################

errabsn4_5=np.zeros(10) #error absoluto del número de partículas en el tiempo 5 s
errreln4_5=np.zeros(10) #error absoluto del número de partículas el tiempo 5 s
for i in range(10):
  errabsn4_5[i]= n4_prom[0]-n4_5[i]
  errreln4_5[i]= (1/(n4_prom[0]))*errabsn4_5[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln4_5)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln4_5*100))


errabsn4_10=np.zeros(10) #error absoluto del número de partículas en el tiempo 10 s
errreln4_10=np.zeros(10) #error absoluto del número de partículas el tiempo 10 s
for i in range(10):
  errabsn4_10[i]= n4_prom[1]-n4_10[i]
  errreln4_10[i]= (1/(n4_prom[1]))*errabsn4_10[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln4_10)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln4_10*100))


errabsn4_20=np.zeros(10) #error absoluto del número de partículas en el tiempo 20 s
errreln4_20=np.zeros(10) #error absoluto del número de partículas el tiempo 20 s
for i in range(10):
  errabsn4_20[i]= n4_prom[2]-n4_20[i]
  errreln4_20[i]= (1/(n4_prom[2]))*errabsn4_20[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln4_20)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln4_20*100))

errabsn4_30=np.zeros(10) #error absoluto del número de partículas en el tiempo 30 s
errreln4_30=np.zeros(10) #error absoluto del número de partículas el tiempo 30 s
for i in range(10):
  errabsn4_30[i]= n4_prom[3]-n4_30[i]
  errreln4_30[i]= (1/(n4_prom[3]))*errabsn4_30[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln4_30)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln4_30*100))

errabsn4_50=np.zeros(10) #error absoluto del número de partículas en el tiempo 50 s
errreln4_50=np.zeros(10) #error absoluto del número de partículas el tiempo 50 s
for i in range(10):
  errabsn4_50[i]= n4_prom[4]-n4_50[i]
  errreln4_50[i]= (1/(n4_prom[4]))*errabsn4_50[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln4_50)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln4_50*100))

errabsn4_80=np.zeros(10) #error absoluto del número de partículas en el tiempo 80 s
errreln4_80=np.zeros(10) #error absoluto del número de partículas el tiempo 80 s
for i in range(10):
  errabsn4_80[i]= n4_prom[5]-n3_80[i]
  errreln4_80[i]= (1/(n4_prom[5]))*errabsn4_80[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln4_80)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln4_80*100))

errabsn4_100=np.zeros(10) #error absoluto del número de partículas en el tiempo 100 s
errreln4_100=np.zeros(10) #error absoluto del número de partículas el tiempo 100 s
for i in range(10):
  errabsn4_100[i]= n4_prom[6]-n4_100[i]
  errreln4_100[i]= (1/(n4_prom[6]))*errabsn4_100[i]
print('El error relativo de cada medida del número de partículas alrededor de 10 segundos',errreln4_100)
print('El error porcentual de cada medida del número de partículas alrededor de 10 segundos',abs(errreln4_100*100))
###############################################################################

errabscm4_5=np.zeros(10) #error absoluto del centro de masa en el tiempo 5 s
errrelcm4_5=np.zeros(10) #error absoluto del centro de masa el tiempo 5 s
for i in range(10):
  errabscm4_5[i]= cm4_prom[0]-cm4_5[i]
  errrelcm4_5[i]= (1/(cm4_prom[0]))*errabscm4_5[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm4_5)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm4_5*100))

errabscm4_10=np.zeros(10) #error absoluto del centro de masa en el tiempo 10 s
errrelcm4_10=np.zeros(10) #error absoluto del centro de masa el tiempo 10 s
for i in range(10):
  errabscm4_10[i]= cm4_prom[1]-cm4_10[i]
  errrelcm4_10[i]= (1/(cm4_prom[1]))*errabscm4_10[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm4_10)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm4_10*100))

errabscm4_20=np.zeros(10) #error absoluto del centro de masa en el tiempo 20 s
errrelcm4_20=np.zeros(10) #error absoluto del centro de masa el tiempo 20 s
for i in range(10):
  errabscm4_20[i]= cm4_prom[2]-cm4_20[i]
  errrelcm4_20[i]= (1/(cm4_prom[2]))*errabscm4_20[i]
print('El error relativo de cada medida del centro de masa alrededor de 20 segundos',errrelcm4_20)
print('El error porcentual de cada medida del centro de masa alrededor de 20 segundos',abs(errrelcm4_20*100))

errabscm4_30=np.zeros(10) #error absoluto del centro de masa en el tiempo 30 s
errrelcm4_30=np.zeros(10) #error absoluto del centro de masa el tiempo 30 s
for i in range(10):
  errabscm4_30[i]= cm4_prom[3]-cm4_30[i]
  errrelcm4_30[i]= (1/(cm4_prom[3]))*errabscm4_30[i]
print('El error relativo de cada medida del centro de masa alrededor de 30 segundos',errrelcm4_30)
print('El error porcentual de cada medida del centro de masa alrededor de 30 segundos',abs(errrelcm4_30*100))


errabscm4_50=np.zeros(10) #error absoluto del centro de masa en el tiempo 50s
errrelcm4_50=np.zeros(10) #error absoluto del centro de masa el tiempo 50s
for i in range(10):
  errabscm4_50[i]= cm4_prom[4]-cm4_50[i]
  errrelcm4_50[i]= (1/(cm4_prom[4]))*errabscm4_50[i]
print('El error relativo de cada medida del centro de masa alrededor de 50 segundos',errrelcm4_50)
print('El error porcentual de cada medida del centro de masa alrededor de 50 segundos',abs(errrelcm4_50*100))

errabscm4_80=np.zeros(10) #error absoluto del centro de masa en el tiempo 80s
errrelcm4_80=np.zeros(10) #error absoluto del centro de masa el tiempo 80s
for i in range(10):
  errabscm4_80[i]= cm4_prom[5]-cm4_80[i]
  errrelcm4_80[i]= (1/(cm4_prom[5]))*errabscm4_80[i]
print('El error relativo de cada medida del centro de masa alrededor de 80 segundos',errrelcm4_80)
print('El error porcentual de cada medida del centro de masa alrededor de 80 segundos',abs(errrelcm4_80*100))

errabscm4_100=np.zeros(10) #error absoluto del centro de masa en el tiempo 100s
errrelcm4_100=np.zeros(10) #error absoluto del centro de masa el tiempo 100s
for i in range(10):
  errabscm4_100[i]= cm4_prom[6]-cm4_100[i]
  errrelcm4_100[i]= (1/(cm4_prom[6]))*errabscm4_100[i]
print('El error relativo de cada medida del centro de masa alrededor de 10 segundos',errrelcm4_100)
print('El error porcentual de cada medida del centro de masa alrededor de 10 segundos',abs(errrelcm4_100*100))
# Out:
# Para 200 partículas
# El error relativo de cada medida del tiempo alrededor de 5 segundos [-0.0577442  -0.00557654  0.05018888  0.03759669  0.01421119 -0.0577442
#   0.04839    -0.00017989 -0.05954308  0.03040115]
# El error porcentual de cada medida del tiempo alrededor de 5 segundos [5.77441986 0.55765425 5.01888829 3.75966901 1.42111891 5.77441986
#  4.83899982 0.01798885 5.95430833 3.04011513]
# El error relativo de cada medida del tiempo alrededor de 10 segundos [ 0.02324673  0.00859543  0.01250244 -0.03438172 -0.04903301  0.01152569
#   0.01250244  0.01054894  0.01640945 -0.01191639]
# El error porcentual de cada medida del tiempo alrededor de 10 segundos [2.32467279 0.85954288 1.25024419 3.43817152 4.90330143 1.15256886
#  1.25024419 1.05489353 1.6409455  1.19163899]
# El error relativo de cada medida del tiempo alrededor de 20 segundos [-0.00683439  0.00752773  0.00356577 -0.00287242  0.00356577 -0.00435816
#   0.00257528 -0.00089144 -0.00188193 -0.0003962 ]
# ...
